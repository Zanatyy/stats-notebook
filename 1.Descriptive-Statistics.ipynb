# %% [markdown]
# # Descriptive Statistics
# Descriptive Statistics is a set of methods to describe and summarize the dataset's basic features in order to interpret and understand the data and how it looks from the inside. The metrics are used to describe the data is called Summary Statistics as it provides concise description of a dataset.
#
# The goal from using these methods is to have a deep understanding of the overall characteristics of the data which is allowed by measuring metrics such as central tendency, variability, and shape.
#
# The key metrics are used are:
#
# 1. **Measures of Central Tendency**: These describe the center of a data set.
#    - **Mean**: The average of the data points.
#    - **Median**: The middle value when the data points are ordered.
#    - **Mode**: The most frequently occurring value.
#
# 2. **Measures of Dispersion**: These describe the spread or variability of the data.
#    - **Range**: The difference between the highest and lowest values.
#    - **Variance**: The average of the squared differences from the mean.
#    - **Standard Deviation**: The square root of the variance, indicating how much the values deviate from the mean.
#
# 3. **Frequency Distributions**: Organizing data into a table showing how often each value occurs.
#
# 4. **Graphs and Charts**: Visual representations like histograms, bar charts, and box plots that help to see patterns and distributions.

# %% [markdown]
# ### 1. Central Tendency

# %% [markdown]
# Measures of central tendency are statistical tools used to describe the central point of a data set. They give an idea of where the center of the data lies. Here are the three main measures:
#
# 1. **Mean**:
#    - **Definition**: The arithmetic average of a data set.
#    - **Calculation**: Sum of all data points divided by the number of data points.
#    $$ \bar{x} = \frac{1}{n} \sum_{i=1}^{n} x_i $$
#       $\bar{x}$ represents the mean, ${n}$ represents the number of samples.
#       - **Example**: For data points 4, 8, and 6, the mean is $$(4 + 8 + 6) / 3 = 6\).
# 2. **Median**:
#    - **Definition**: The middle value of a data set when it is ordered from smallest to largest. If there’s an even number of observations, it’s the average of the two middle numbers.
#    - **Calculation**: Order the data, then find the middle value (or average the two middle values if even).
#
#    For odd number of samples the calculation as followed:
#    $$ \text{Median} = x_{\left(\frac{n+1}{2}\right)}$$
#    For even number of samples, we sum the two middle numbers and divide them by the number of samples:
#    $$\text{Median} = \frac{1}{2} \left( x_{\left(\frac{n}{2}\right)} + x_{\left(\frac{n}{2} + 1\right)} \right)$$
#    ${n}$ represents the number of samples.
#    - **Example**: For data points 3, 7, and 9, the median is 7. For data points 2, 5, 8, and 10, the median is (5 + 8) / 2 = 6.5.
# 3. **Mode**:
#    - **Definition**: The value that appears most frequently in a data set.
#    - **Calculation**: Identify the most common value(s).
#    - **Example**: For data points 1, 2, 2, 3, and 4, the mode is 2. If no number repeats, there’s no mode.

# %% [markdown]
# Code:

# %%
import numpy as np
from scipy import stats

# Sample data
data = [10, 20, 30, 40, 50, 20]

# Calculate the mean
mean = np.mean(data)

# Calculate the median
median = np.median(data)

# Calculate the mode
mode = stats.mode(data)

# Print results
print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Mode: {mode.mode}")
# Out:
# Mean: 28.333333333333332
# Median: 25.0
# Mode: 20

# %% [markdown]
# ### Understanding What We Are Measuring
# Measurement of Central Tendency gives us an accurate description of how the data center looks like and how it looks on a distribution graph. We can easily know if the data is skewed or not.
# Skewed data is a data which its distribution is not symmetrical. It's a dataset which its distribution curve appears distorted to the left or right.
# Usually the median is the best indicator for the skewness of the data.
#
# The data is said to be:
# - Left Skewed when it has a tail on the negative side of the graph which reflects on the graph as he distribution has a long left tail, and the measurements as: Mode > Median > Mean.
#
# - Normal Distribution: When the Mean, Median and Mode are very close to each other.
#
# - Right Skewed when it has a tail on the positive side of the graph which reflects on the graph as he distribution has a long right tail, and the measurements as: Mean > Median > Mode.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In summary, for skewed distributions, the median often provides a better measure of central tendency than the mean, as it is less influenced by extreme values (Outliers).

# %% [markdown]
# ### 2. Measures of Dispersion
# Measurement of how likely the data will vary off the average or the mean value is the dispersion measurement which will help us to understand more how the data looks like on a distribution graph.

# %% [markdown]
# In statistics, measures of dispersion help us understand how spread out or concentrated together the data is. They show whether the data points are close to each other or scattered and varrying over a wide range.

# %% [markdown]
# The key measures of dispersion:
#
# 1. **Range**:
#    - **Definition**: The difference between the maximum and minimum values in a data set.
#    - **Calculation**:
#      $$
#      \text{Range} = \text{Max} - \text{Min}
#      $$
#    - **Example**: For the data set {3, 7, 8, 10}, the range is $$\text{Range} = 10 - 3 = 7$$
#
#
# 2. **Variance**:
#    - **Definition**: The average of the squared differences from the mean. It measures how much the values deviate from the mean.
#    - **Calculation**:
#      $$
#      \text{Variance} = \frac{1}{n} \sum_{i=1}^{n} (x_i - \bar{x})^2
#      $$
#      where $ \bar{x} $ is the mean and $ {x_i} $ are the data points.
#    - **Example**: For the data set $ \{4, 8, 6\} $ with a mean of 6, the variance is
#      $
#      \frac{1}{3} \left[(4 - 6)^2 + (8 - 6)^2 + (6 - 6)^2\right] = \frac{1}{3} \left[4 + 4 + 0\right] = \frac{8}{3} \approx 2.67
#      $
#
# 3. **Standard Deviation**:
#    - **Definition**: The square root of the variance. It provides a measure of dispersion in the same units as the data.
#    - **Calculation**:
#      $$ \text{Standard Deviation} = \sqrt{Variance} $$
#    - **Example**: For the variance calculated above as $\frac{8}{3} \approx 2.67$, the standard deviation is $\sqrt{2.67} \approx 1.63\$.
#
# 4. **Interquartile Range (IQR)**:
#    - **Definition**: The range within which the central 50% of the data lie. It is the difference between the first quartile (Q1) and the third quartile (Q3).
#    - **Calculation**:
#      $$ \text{IQR} = Q3 - Q1 $$
#    - **Example**: For a data set with Q1 = 25 and Q3 = 75, the IQR is $ 75 - 25 = 50 $.
#
# 5. **Mean Absolute Deviation (MAD)**:
#    - **Definition**: The average of the absolute differences between each data point and the mean.
#    - **Calculation**:
#      $$
#      \text{MAD} = \frac{1}{n} \sum_{i=1}^{n} |x_i - \bar{x}|
#      $$
#    - **Example**: For the data set \{4, 8, 6\} with a mean of 6, the MAD is
#      $$
#      \text{MAD} = \frac{1}{3} \left[|4 - 6| + |8 - 6| + |6 - 6|\right] = \frac{1}{3} \left[2 + 2 + 0\right] = \frac{4}{3} \approx 1.33
#      $$
#
# Each measure of dispersion provides different insights into the variability of the data, and using them together can give a more comprehensive understanding of the data set’s spread. However, When we compare two datasets we dont use those measurement methods as an absolute, instead we use Coefficients of Deviations.

# %% [markdown]
# **Coefficient of Dispersion (COD)**
# 1. **Definition**:
#    - The Coefficient of Dispersion is a relative measure of dispersion that expresses the variability of a data set divided by the mean. It provides a normalized way to compare dispersion across different datasets.
#
# 2. **Formula**:
#    - The Coefficient of Dispersion is often calculated as:
#      $$
#      \text{COD} = \frac{\text{Mean Absolute Deviation}}{\text{Mean}} \times 100\%
#      $$
#    - Alternatively, it can be expressed using the ratio of the range to the mean:
#      $$
#      \text{COD} = \frac{\text{Range}}{\text{Mean}} \times 100\%
#      $$
#
# 3. **Interpretation**:
#    - A higher COD indicates greater dispersion or variability relative to the mean, meaning the data points are more spread out.
#    - A lower COD indicates less variability, meaning the data points are more closely grouped around the mean.
#
# 4. **Example**:
#    - Suppose you have a dataset with a mean of 50 and a mean absolute deviation of 10. The COD would be:
#      $$
#      \text{COD} = \frac{10}{50} \times 100\% = 20\%
#      $$
#    - This means the dispersion is 20% of the mean.
#
# The Coefficient of Dispersion is useful for comparing the relative spread of different datasets and understanding the proportion of variability in relation to the central value.

# %%
import numpy as np
from scipy import stats

# Sample data
data = [10, 20, 30, 40, 50, 20]

# Convert to numpy array for convenience
data_array = np.array(data)

# Calculate the mean
mean = np.mean(data_array)

# Calculate the standard deviation
std_dev = np.std(data_array, ddof=0)  # ddof=0 for population std deviation

# Calculate the mean absolute deviation
mad = np.mean(np.abs(data_array - mean))

# Calculate the coefficient of variation
cod = std_dev / mean

# Print results
print(f"Mean: {mean}")
print(f"Standard Deviation: {std_dev}")
print(f"Mean Absolute Deviation: {mad}")
print(f"Coefficient of Variation: {cod}")
# Out:
# Mean: 28.333333333333332
# Standard Deviation: 13.437096247164249
# Mean Absolute Deviation: 11.666666666666666
# Coefficient of Variation: 0.4742504557822676

# %% [markdown]
# ### 3. Frequency Distribution
# A frequency distribution is a representation, either in a graphical or in a table, that displays the number of observations or samples within a given interval. The frequency is how often a value occurs or observed in an interval, while the distribution is the pattern of frequency of the variable or how it looks as a graph.

# %% [markdown]
# A frequency distribution is a way to organize and summarize data by showing how often each value or range of values occurs. It provides a clear view of the distribution of the data and helps to identify patterns, trends, and outliers. Here’s how it works:
#
# **Components** to use when we want to do frequency distribution:
#
# 1. **Classes/Bins**:
#    - The first thing to do is determine or set the intervals or categories that group the data into ranges.
#    - **Example**: For a set of exam scores, you might create classes like 0-10, 11-20, 21-30, etc.
#
# 2. **Frequency**:
#    - We calculate or count the number of data points or observations that fall into each class or bin.
#    - **Example**: If 15 students scored between 0-10, the frequency for that class is 15.
#
# 3. **Cumulative Frequency**:
#    - The running total of frequencies up to and including the current class. In other wods, the sum of the number of the observations from the current class including previous classes.
#    - **Example**: If the frequencies for the classes are 15, 20, and 10, the cumulative frequencies would be 15, 35, and 45 .
#
# 4. **Relative Frequency**:
#    - **Definition**: The frequency of each class divided by the total number of data points, often expressed as a percentage.
#    - **Example**: If there are 100 total scores and 15 fall into the 0-10 range, the relative frequency is $$ \frac{15}{100} \times 100\% = 15\% $$.
#
# ### **Creating a Frequency Distribution Table**
#
# 1. **List the Classes/Bins**: Determine the range of values and divide them into intervals.
# 2. **Count the Frequency**: Tally how many data points fall into each class.
# 3. **Calculate Relative and Cumulative Frequencies** (if needed): Compute these to get a more detailed view.
#
# ### **Example**
#
# Suppose you have the following data on the number of books read by a group of people: 1, 2, 2, 3, 3, 3, 4, 4, 4, 4, 5, 5.
#
# **Frequency Distribution Table**:
#
# | Number of Books | Frequency | Relative Frequency | Cumulative Frequency |
# |-----------------|-----------|--------------------|-----------------------|
# | 1               | 1         | 1/12 ≈ 8.33%       | 1                     |
# | 2               | 2         | 2/12 ≈ 16.67%      | 3 (1+2)               |
# | 3               | 3         | 3/12 ≈ 25.00%      | 6 (3+3)               |
# | 4               | 4         | 4/12 ≈ 33.33%      | 10 (6+4)              |
# | 5               | 2         | 2/12 ≈ 16.67%      | 12 (10+2)             |
#
# In this example:
# - The **Frequency** column shows how many people read each number of books.
# - The **Relative Frequency** gives the proportion of each class.
# - The **Cumulative Frequency** adds up frequencies to show the total up to each class.

# %% [markdown]
# **4. Visual Representation (Graphs)**
#
# A statistical Graph is a visual representation of the data which is used to understand the data more in order to analyze and spot patterns, trends and relationships between the features.
# Graphs help in summarizing, analyzing, and communicating data effectively. They can illustrate distributions, compare values, show trends, and reveal correlations.
# Commonly used statistical graphs:
#
# ### Common Types of Statistical Graphs
#
# 1. **Histogram**: Displays the frequency distribution of continuous data by dividing the data into bins and showing the count of observations within each bin.
#
# 2. **Bar Chart**: Compares categorical or discrete data by using bars of varying lengths to represent the frequency or value of each category.
#
# 3. **Pie Chart**: Shows the proportion of different categories as slices of a whole, representing the percentage of each category.
#
# 4. **Box Plot (Box-and-Whisker Plot)**: Summarizes data distribution using the median, quartiles, and potential outliers, providing insights into data spread and symmetry.
#
# 5. **Scatter Plot**: Shows the relationship between two continuous variables by plotting data points on a Cartesian plane.
#
# 6. **Line Graph**: Illustrates trends over time or relationships between variables by connecting data points with a line.
#
# 7. **Frequency Polygon**: Represents the distribution of a continuous variable by connecting the midpoints of histogram bins with a line.
#
# 8. **Dot Plot**: Displays individual data points along a number line, showing the frequency of each value.
#
# 9. **Heatmap**: Visualizes data in a matrix format with colors representing different values, useful for showing intensity and correlations.
#
# ### Purpose and Use
#
# - **Exploratory Data Analysis**: Helps in understanding the data structure, distribution, and relationships before applying statistical models.
# - **Presentation**: Used to communicate findings clearly and effectively to audiences.
# - **Decision Making**: Assists in making informed decisions based on data insights.
#
# Statistical graphs are essential tools in data analysis and research, enabling clearer interpretation and communication of data.

# %% [markdown]
# ### Code:
# There's a lot of tools to use in order to plot such as Google Sheets, Excel, R or Python.
#
# Python has a lot of plotting libraries such as MatPlotLib and Seaborn which makes it very convenient for Data Analysis/Science and Machine Learning applications.

# %%
# Importing the plotting library
import matplotlib.pyplot as plt 

# Sample Data
books = [1, 2, 3, 4, 5]
frequency = [1, 2, 3, 4, 2]

# Create a figure with multiple subplots
plt.figure(figsize=(18, 15))
'''
Plotting Code components:
subplot ->   The position of the subplot described (nrows, ncols, index)
title   ->   Plot Title
xtitle  ->   X Label
ytitle  ->   Y Label
'''
# Histogram
plt.subplot(3, 3, 1)
plt.hist(books, bins=[0.5, 1.5, 2.5, 3.5, 4.5, 5.5], weights=frequency, edgecolor='black', alpha=0.7)
plt.title('Histogram')
plt.xlabel('Number of Books')
plt.ylabel('Frequency')

# Bar Chart
plt.subplot(3, 3, 2)
plt.bar(books, frequency, edgecolor='black', alpha=0.7)
plt.title('Bar Chart')
plt.xlabel('Number of Books')
plt.ylabel('Frequency')

# Frequency Polygon
plt.subplot(3, 3, 3)
plt.plot(books, frequency, marker='o', linestyle='-', color='blue')
plt.title('Frequency Polygon')
plt.xlabel('Number of Books')
plt.ylabel('Frequency')
plt.grid(True)

# Pie Chart
plt.subplot(3, 3, 4)
plt.pie(frequency, labels=books, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart')

# Box Plot
plt.subplot(3, 3, 5)
plt.boxplot([books], vert=False, patch_artist=True)
plt.title('Box Plot')
plt.xlabel('Number of Books')

# Scatter Plot
plt.subplot(3, 3, 6)
plt.scatter(books, frequency, color='red')
plt.title('Scatter Plot')
plt.xlabel('Number of Books')
plt.ylabel('Frequency')

# Line Graph
plt.subplot(3, 3, 7)
plt.plot(books, frequency, marker='o', linestyle='-', color='green')
plt.title('Line Graph')
plt.xlabel('Number of Books')
plt.ylabel('Frequency')


# Dot Plot
plt.subplot(3, 3, 9)
plt.plot(books, frequency, 'o', linestyle='None')
plt.title('Dot Plot')
plt.xlabel('Number of Books')
plt.ylabel('Frequency')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# As box plots can be confusing at first, here's a diagram that explains how to interpret the plot:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# $Q_0$ is the the minimum sample, $Q_1$ is the first quartile, $Q_2$ is the median, $Q_3$ is the third quartile, $Q_4$ is the maximum sample.
#
# It's noted that the box's beginning is on the first quartile and its ending is on the third one. while The line starts on the minimum value and ends on the maximum value.

# %% [markdown]
# ### Tabulation and Cross-Tabulation
# Tabulation is the process of placing classified data in a table. The tabular form is arranging it in rows and columns. It's a very useful method to summarize datasets -especiall for large ones- to make it easier to read and spot patterns, relationships and trends.

# %% [markdown]
# Tabulation is the process of organizing data into tables to facilitate analysis and interpretation. It involves arranging data in rows and columns to summarize and present information in a clear and structured manner. This method is particularly useful for large datasets, making it easier to see patterns, relationships, and trends.
#
# 1. **Frequency Table**:
#    - **Purpose**: Shows how often each value or range of values occurs in a dataset.
#    - **Example**: A table displaying the number of students who scored within different score ranges on an exam.
#
# | Age Group | Total     |
# |-----------|-----------|
# | 18-25     | 60        |
# | 26-35     | 55        |
# | 36-45     | 50        |
#
#
#
# 2. **Contingency Table (Cross-Tabulation)**:
#    - **Purpose**: Displays the relationship between two or more categorical variables.
#    - **Example**: A table showing the number of people in different age groups and their preferences for different types of products and the different relationships.
#
# | Age Group  | Product A | Product B | Product C | Row Totals|
# |------------|-----------|-----------|-----------|-----------|
# | 18-25      | 20        | 30        | 10        | 60        |
# | 26-35      | 25        | 20        | 15        | 55        |
# | 36-45      | 15        | 25        | 20        | 50        |
# |Column Total| 60        | 75        | 45        |
#
# To compute the row percentages and column percentages, we'll create two new tables.
#
# **1. Row Percentages Table**
#
# Row percentages show the proportion of people in each age group who prefer each product.
#
# For each cell, the formula is:
#
# $$
# \text{Row Percentage} = \left( \frac{\text{Cell Value}}{\text{Row Total}} \right) \times 100
# $$
#
# | Age Group | Product A (%) | Product B (%) | Product C (%) |
# |-----------|---------------|---------------|---------------|
# | 18-25     | $$ \frac{20}{60} \times 100 = 33.33\% $$ | $$ \frac{30}{60} \times 100 = 50\% $$ | $$ \frac{10}{60} \times 100 = 16.67\% $$ |
# | 26-35     | $$ \frac{25}{55} \times 100 = 45.45\% $$ | $$ \frac{20}{55} \times 100 = 36.36\% $$ | $$ \frac{15}{55} \times 100 = 27.27\% $$ |
# | 36-45     | $$ \frac{15}{50} \times 100 = 30\% $$    | $$ \frac{25}{50} \times 100 = 50\% $$    | $$ \frac{20}{50} \times 100 = 40\% $$    |
#
# ### 2. **Column Percentages Table**
#
# Column percentages show the proportion of people from each age group who prefer a specific product.
#
# For each cell, the formula is:
#
# $$
# \text{Column Percentage} = \left( \frac{\text{Cell Value}}{\text{Column Total}} \right) \times 100
# $$
#
# First, we need to calculate the **column totals**:
# - Product A Total:  20 + 25 + 15 = 60
# - Product B Total:  30 + 20 + 25 = 75
# - Product C Total:  10 + 15 + 20 = 45
#
# Now, we compute the percentages:
#
# | Age Group | Product A (%) | Product B (%) | Product C (%) |
# |-----------|---------------|---------------|---------------|
# | 18-25     | $$ \frac{20}{60} \times 100 = 33.33\% $$ | $$ \frac{30}{75} \times 100 = 40\% $$ | $$ \frac{10}{45} \times 100 = 22.22\% $$ |
# | 26-35     | $$ \frac{25}{60} \times 100 = 41.67\% $$ | $$ \frac{20}{75} \times 100 = 26.67\% $$ | $$ \frac{15}{45} \times 100 = 33.33\% $$ |
# | 36-45     | $$ \frac{15}{60} \times 100 = 25\% $$    | $$ \frac{25}{75} \times 100 = 33.33\% $$ | $$ \frac{20}{45} \times 100 = 44.44\% $$ |

# %% [markdown]
# ## Elementary Statistical Testing

# %% [markdown]
# Elementary statistical testing refers to the basic methods used to make decisions or draw conclusions from data. These tests help determine whether observed patterns or differences are real or occurred by chance. Here are some key aspects:
#
# 1. **Null and Alternative Hypothesis**: Like in all hypothesis testing, we start with the null hypothesis (H₀) that assumes no effect or no difference, and the alternative hypothesis (H₁) that suggests a real effect or difference.
#
# 2. **Common Types of Tests**:
#    - **Z-test**: Used to compare sample data to the population when the sample size is large (typically \(n > 30\)) and the population variance is known.
#    - **T-test**: Used when the sample size is small or the population variance is unknown, typically to compare means.
#    - **Chi-square test**: Used for categorical data to test relationships or compare observed frequencies to expected ones.
#
# 3. **Significance Level (α)**: Commonly set at 0.05, this is the threshold for determining if a result is statistically significant. If the result is below α, we reject the null hypothesis.
#
# 4. **P-value**: The p-value tells us how likely it is that the observed data would occur if the null hypothesis were true. A small p-value (less than α) suggests that the observed result is unlikely to be due to chance alone, leading us to reject the null hypothesis.
#
# Elementary statistical testing is foundational in analyzing data, used in everything from comparing averages to examining relationships between variables.

# %% [markdown]
# ### Hypothesis Testing
# Hypothesis testing is a way to make decisions or draw conclusions about a population based on data from a sample. It helps us figure out if something we observe (like a difference or an effect) is real or just happened by chance.
#
# 1. **Null Hypothesis (H₀)**: This is a starting assumption that nothing has changed, or there’s no effect. We assume it's true until we have evidence to prove otherwise.
#
# 2. **Alternative Hypothesis (H₁)**: This is what we're trying to prove — that there is a change, effect, or difference.
#
# We collect data, calculate a test result, and then decide whether the evidence is strong enough to reject the null hypothesis and support the alternative hypothesis.
#
# 3. **Test Statistic**: A test statistic is calculated from the sample data and is used to assess the strength of the evidence against the null hypothesis. The type of test statistic depends on the hypothesis test being conducted. (ex: t-statistic)
#
# 4. **Significance Level**: The threshold for the t-statistic to reject the null hypothesis. Commonly used thresholds are 5% or 1%.
#
# 5. **P-Value**:  The p-value is the probability of obtaining a test statistic as extreme as the one observed, assuming the null hypothesis is true. If the p-value is less than the significance level α, we reject the null hypothesis.

# %% [markdown]
# ### Types of Tests:
# Most commonly used tests are testing for a mean. The goal is to make inferences about the population mean based on sample data. Commonly used tests for a mean are:
#
# #### **1. T-Test/Z-Test**: The t-test and z-test are both statistical tests used to determine if there are significant differences between means.
#
# Before using we have to assume that the observations are independent and come from a Normal distribution.
#
# Formula:
#
# $$
# t = \frac{\bar{X} - \mu_0}{s / \sqrt{n}}
# $$
#
# We can also retrieve the t-statistic from the table by calculating Degrees of Freedom (df):
#
# $$ {df} = {n}-1 $$
# as ${n}$ is number of samples
#
# The critical value of t-statistic should look like this:
#
# Degrees of Freedom | 0.10  | 0.05  | 0.01  | 0.001 |
# |------------------|-------|-------|-------|-------|
# 1                  | 6.314 | 12.71 | 63.66 | 636.62|
# 2                  | 2.920 | 4.303 | 9.925 | 22.327|
# 3                  | 2.353 | 3.182 | 5.841 | 10.215|
# 4                  | 2.132 | 2.776 | 4.604 | 7.173 |
# 5                  | 2.015 | 2.571 | 4.032 | 5.893 |
# 6                  | 1.943 | 2.447 | 3.707 | 5.208 |
# 7                  | 1.895 | 2.364 | 3.499 | 4.785 |
# 8                  | 1.860 | 2.306 | 3.355 | 4.501 |
# 9                  | 1.833 | 2.262 | 3.250 | 4.297 |
# 10                 | 1.812 | 2.228 | 3.169 | 4.144 |
#
# We use T-Test when the number of samples < 30 or when the standard deviation is unknown, Otherwise Z-Test is used.
#
# **Central Limit Theorem (CLT)**: The theorem states that the distribution of the sample mean will approach a normal distribution as the sample size becomes large, regardless of the original population's distribution. According to the theorem we use T-Test when we dont know the standard deviation.
#
# **Types of the test depending on the sample**:
#
# ##### 1. **One-Sample t-Test**:
#    - **Objective**: Test if the sample mean is significantly different from a known value (e.g., a population mean).
#    - **When to Use**: When you have one sample and want to compare its mean to a known value.
#    - **Code**:

# %%
import numpy as np
from scipy import stats

# Sample data
data = [2.3, 2.9, 3.1, 2.8, 3.0]

# Hypothesized population mean
population_mean = 3.0

# Perform one-sample t-test
t_stat, p_value = stats.ttest_1samp(data, population_mean)

print(f"t-statistic: {t_stat}")
print(f"p-value: {p_value}")
# Out:
# t-statistic: -1.2923246855119326
# p-value: 0.2658472860753787

# %% [markdown]
# ##### 2. **Independent Samples t-Test**:
#    - **Objective**: Compare the means of two independent groups to determine if they are significantly different.
#    - **When to Use**: When you have two separate groups and want to compare their means.

# %%
import numpy as np
from scipy import stats

# Sample data for two groups
group1 = [2.3, 2.9, 3.1, 2.8, 3.0]
group2 = [3.2, 3.5, 3.6, 3.3, 3.7]

# Perform independent two-sample t-test
t_stat, p_value = stats.ttest_ind(group1, group2)

print(f"t-statistic: {t_stat}")
print(f"p-value: {p_value}")
# Out:
# t-statistic: -3.8247315498700623
# p-value: 0.00505561083180125

# %% [markdown]
# ##### 3. **Paired Samples t-Test (Dependent)**:
#    - **Objective**: Compare means from the same group at different times or under different conditions.
#    - **When to Use**: When you have paired or matched observations, such as before-and-after measurements on the same subjects.

# %%
import numpy as np
from scipy import stats

# Sample data before and after treatment
before = [2.3, 2.9, 3.1, 2.8, 3.0]
after = [2.8, 3.2, 3.4, 3.1, 3.3]

# Perform paired sample t-test
t_stat, p_value = stats.ttest_rel(before, after)

print(f"t-statistic: {t_stat}")
print(f"p-value: {p_value}")
# Out:
# t-statistic: -8.500000000000004
# p-value: 0.0010505780707892483

# %% [markdown]
# #### **2. ANOVA Test**: An extension for T-Test for more than two groups
# ANOVA (Analysis of Variance) is a statistical test used to determine if there are significant differences among the means of three or more groups. It helps assess whether at least one group mean is different from the others, based on sample data.
#
# **Key Concepts**
#
# - **Purpose**: To compare the means of multiple groups to see if there are statistically significant differences between them.
# - **Types**:
#   - **One-Way ANOVA**: Tests differences among the means of three or more independent groups based on one factor (e.g., comparing the effectiveness of three different teaching methods).
#   - **Two-Way ANOVA**: Tests differences among means based on two factors and their interaction (e.g., examining the effects of teaching method and class size on student performance).
#
# **Assumptions**
# 1. **Independence**: Observations in each group should be independent of each other.
# 2. **Normality**: Data in each group should be approximately normally distributed (especially important for small sample sizes).
# 3. **Homogeneity of Variances**: The variances among the groups should be roughly equal.
#
# **Procedure**
# 1. **Formulate Hypotheses**:
#    - **Null Hypothesis (H0)**: All group means are equal.
#    - **Alternative Hypothesis (H1)**: At least one group mean is different.
#
# 2. **Calculate F-Statistic**: Compares the variance between groups to the variance within groups.
#
# 3. **Compare F-Statistic to Critical Value**: Determine if the observed F-Statistic is significantly large compared to a critical value from the F-distribution.
#
# ANOVA is widely used in experimental designs and research to evaluate the effects of different treatments or conditions.

# %% [markdown]
# #### **Non-parametric Tests**
# Non-parametric tests are statistical methods used when data doesn't meet the assumptions of parametric tests, such as normal distribution or equal variances. They rely on the ranks of the data rather than the raw data values. These tests are ideal for ordinal, skewed, or non-normally distributed data
#
# Common tests used are:

# %% [markdown]
# ### **1. Chi-Square**
# The Chi-Square Test is a non-parametric test used to assess the association between categorical variables or to compare observed frequencies with expected frequencies. There are two primary types of Chi-Square Tests:
#
# #### **1. Chi-Square Test of Independence**
#
# **Purpose**: To determine if there is a significant association between two categorical variables.
#
# **Example**: Testing if there is a relationship between gender (male/female) and voting preference (yes/no).
#
# **Steps**:
#
# 1. **Create a Contingency Table**: Construct a table that displays the frequency counts for each combination of categories for the two variables.
#
# 2. **Calculate Expected Frequencies**: For each cell in the table, calculate the expected frequency under the assumption that the variables are independent. The formula is:
#    $$
#    E_{ij} = \frac{(R_i \cdot C_j)}{N}
#    $$
#    Where:
#    - $E_{ij}$ = Expected frequency for cell $(i, j)$
#    - $R_{i}$ = Total frequency for row $(i)$
#    - $C_{J}$ = Total frequency for column $(j)$
#    - ${N}$ = Total number of observations
#
# 3. **Compute the Chi-Square Statistic**:
# The Chi-Square statistic is calculated as follows:
#
# $$
# \chi^2 = \sum \frac{(O_{ij} - E_{ij})^2}{E_{ij}}
# $$
#
# where:
# - $O_{ij}$ = Observed frequency for cell $(i, j)$
# - $E_{ij}$ = Expected frequency for cell $(i, j)$
#
#
# 4. **Determine Degrees of Freedom**: Calculate the degrees of freedom using:
#    $$
#    \text{df} = (r - 1) \times (c - 1)
#    $$
#    Where:
#    - r = Number of rows
#    - c = Number of columns
#
# 5. **Compare to Critical Value**: Compare the calculated \(\chi^2\) value to the critical value from the Chi-Square distribution table with the appropriate degrees of freedom or compute the p-value.
#
# 6. **Draw Conclusions**: If the p-value is less than the significance level (e.g., 0.05), reject the null hypothesis and conclude that there is a significant association between the variables.

# %%
import numpy as np
from scipy import stats

# Example contingency table: rows are gender (Male, Female) and columns are voting preferences (Yes, No)
data = np.array([[30, 10],   # Male
                 [20, 40]])  # Female

# Perform Chi-Square Test of Independence
chi2_stat, p_value, dof, expected = stats.chi2_contingency(data)

print("Chi-Square Statistic:", chi2_stat)
print("p-Value:", p_value)
print("Degrees of Freedom:", dof)
print("Expected Frequencies Table:")
print(expected)
# Out:
# Chi-Square Statistic: 15.041666666666666
# p-Value: 0.00010516355403363098
# Degrees of Freedom: 1
# Expected Frequencies Table:
# [[20. 20.]
#  [30. 30.]]

# %% [markdown]
# #### **2. Chi-Square Test of Goodness of Fit**
#
# **Purpose**: To determine if a sample distribution matches an expected distribution.
#
# **Example**: Testing if the observed distribution of colors in a bag of candies fits the expected proportions.
#
# **Steps**:
#
# 1. **State the Expected Frequencies**: Define the expected proportions or frequencies based on a theoretical distribution.
#
# 2. **Compute the Chi-Square Statistic**:
#    $$
#    \chi^2 = \sum \frac{(O_i - E_i)^2}{E_i}
#    $$
#    Where:
#    - $O_i$ = Observed frequency for category $i$
#    - $E_i$ = Expected frequency for category $i$
# 3. **Determine Degrees of Freedom**: Calculate the degrees of freedom using:
#    $$
#    \text{df} = k - 1
#    $$
#    Where:
#    - $k$ = Number of categories
#
# 4. **Compare to Critical Value**: Compare the calculated $\chi^2$ value to the critical value from the Chi-Square distribution table with the appropriate degrees of freedom or compute the p-value.
#
# 5. **Draw Conclusions**: If the p-value is less than the significance level, reject the null hypothesis and conclude that the observed distribution differs significantly from the expected distribution.
#
# The Chi-Square Test is widely used in categorical data analysis and helps determine if there are significant deviations from what is expected or if there is an association between categorical variables.

# %%
import numpy as np
from scipy import stats

# Observed frequencies of candies (e.g., Red, Blue, Green, Yellow)
observed = np.array([20, 30, 10, 10])

# Expected frequencies (assuming equal distribution)
expected = np.array([17.5, 17.5, 17.5, 17.5])

# Perform Chi-Square Test of Goodness of Fit
chi2_stat, p_value = stats.chisquare(f_obs=observed, f_exp=expected)

print("Chi-Square Statistic:", chi2_stat)
print("p-Value:", p_value)
# Out:
# Chi-Square Statistic: 15.714285714285715
# p-Value: 0.0012976436580202741

# %% [markdown]
# Next tests use rank sums instead of the difference in the mean of the sample. The advantage of taking the rank sums rather than the difference in means is that the data need not be normally distributed.

# %% [markdown]
# ### **2. Mann-Whitney U Test**
#
# - **Purpose**: To compare differences between two independent groups when the data is not normally distributed.
# - **Example**: Comparing scores from two different teaching methods.
# - **Formula**:
#   $$
#   U = R - \frac{n(n + 1)}{2}
#   $$
#   Where \(R\) is the sum of ranks for the group and \(n\) is the number of observations.

# %%
from scipy import stats

# Sample data for two independent groups
group1 = [23, 45, 67, 89, 12]
group2 = [34, 56, 78, 90, 23]

# Perform the Mann-Whitney U test
u_statistic, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')

# Print results
print(f"Mann-Whitney U Statistic: {u_statistic}")
print(f"p-Value: {p_value}")
# Out:
# Mann-Whitney U Statistic: 9.5
# p-Value: 0.6004018480969686

# %% [markdown]
# ### **3. Wilcoxon Signed-Rank Test**
#
# - **Purpose**: To compare two related samples or paired observations.
# - **Example**: Comparing pre-treatment and post-treatment scores from the same subjects.
# - **Formula**:
#   $$
#   W = \text{min}(W^+, W^-)
#   $$
#   Where \(W^+\) and \(W^-\) are the sums of ranks for positive and negative differences, respectively.

# %%
from scipy import stats

# Sample data: paired observations before and after treatment
before = [15, 20, 18, 24, 29]
after = [21, 25, 18, 23, 28]

# Perform the Wilcoxon Signed-Rank Test
statistic, p_value = stats.wilcoxon(before, after)

# Print results
print(f"Wilcoxon Signed-Rank Statistic: {statistic}")
print(f"p-Value: {p_value}")
# Out:
# Wilcoxon Signed-Rank Statistic: 3.0
# p-Value: 0.4614509878333607

# %% [markdown]
# ### **4. Kruskal-Wallis H Test**
#
# - **Purpose**: To compare medians among three or more independent groups. Ideal usage is when the data is not normally distributed.
# - **Example**: Comparing median salaries among different job positions.
# - **Formula**:
#   $$
#   H = \frac{12}{N(N + 1)} \sum \frac{R_j^2}{n_j} - 3(N + 1)
#   $$
#   Where $(R_j)$ is the sum of ranks for group $(j)$, $(n_j)$ is the number of observations in group $(j)$, and $(N)$ is the total number of observations.
#
#   The test is very similar to ANOVA tests but instead of using the mean of every dataset we sort the data by ranks then we use it to calculate our statistic so we compare them to each other. Which gives us an advantage of being able to use it when ANOVA assumptions are violated or the data is not normally distributed.

# %% [markdown]
# ### **5. Friedman Test**
#
# - **Purpose**: To compare medians among three or more related groups.
# - **Example**: Comparing ratings of different products by the same group of people over time.
# - **Formula**:
#   $$
#   \chi^2_F = \frac{12}{n k (k + 1)} \left( \sum_{j=1}^k R_j^2 - \frac{k (k + 1)^2}{4} \right)
#   $$
#   Where \(R_j\) is the sum of ranks for treatment \(j\), \(n\) is the number of subjects, and \(k\) is the number of treatments.

# %% [markdown]
# ### **6. Spearman’s Rank Correlation**
#
# - **Purpose**: To measure the strength and direction of the monotonic relationship between two variables.
# - **Example**: Assessing the relationship between the ranks of students' performances in two subjects.
# - **Formula**:
#   $$
#   \rho = 1 - \frac{6 \sum d_i^2}{n (n^2 - 1)}
#   $$
#   Where \(d_i\) is the difference between the ranks of each pair of observations, and \(n\) is the number of observations.

# %% [markdown]
# ### **7. Kendall’s Tau**
#
# - **Purpose**: To measure the strength and direction of association between two variables, similar to Spearman's rank correlation but with a different calculation method.
# - **Example**: Examining the relationship between two ranked preferences.
# - **Formula**:
#   $$
#   \tau = \frac{(C - D)}{\sqrt{(C + D + T) \times (C + D + U)}}
#   $$
#   Where \(C\) is the number of concordant pairs, \(D\) is the number of discordant pairs, \(T\) is the number of ties only in the first variable, and \(U\) is the number of ties only in the second variable.
#
# These non-parametric tests are useful for analyzing data that does not meet the assumptions of parametric tests or when dealing with ordinal data.
